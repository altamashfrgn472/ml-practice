# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y = True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_, reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238] 151.88331005254167

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
X_train.shape
# Out:
# (353, 10)

# %%
class SGDRegressor:
    def __init__(self, learning_rate, epochs):
        self.lr = learning_rate
        self.coef_ = None
        self.intercept_ = None
        self.epochs = epochs

    def fit(self, X_train, y_train):
        self.mean_ = X_train.mean(axis = 0)
        self.std_ = X_train.std(axis = 0)

        X_train = (X_train - self.mean_) / self.std_

        
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):

            #y_hat = np.dot(X_train, self.coef) + self.intercept_
            #intercept_der = -2 * np.mean(y_train - y_hat)
            #self.intercept_ = self.intercept_ - (lr * intercept_der)
            
            #coef_der = -2 * np.dot((y_train - y_hat), X_train) / X_train.shape[0]
            #self.coef_ = self.coef_ - (lr * coef_der)

            #print(self.intercept_, self.coef_)

            for j in range(X_train.shape[0]):
                idx = np.random.randint(0, X_train.shape[0])

                y_hat = np.dot(X_train[idx], self.coef_) + self.intercept_

                intercept_der = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((y_train[idx] - y_hat), X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
        print(self.coef_, self.intercept_)


    def predict(self, X_test):
        X_test = (X_test - self.mean_) / self.std_
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
y_train.shape
# Out:
# (353,)

# %%
reg.coef_.shape
# Out:
# (10,)

# %%
reg.intercept_.shape
# Out:
# ()

# %%
sgd = SGDRegressor(learning_rate = 0.01, epochs = 42)

# %%
import time
start = time.time()
sgd.fit(X_train, y_train)
print("time taken is",time.time() - start)
# Out:
# [ -5.80285655 -10.91265325  33.1649478   13.75917818 -41.78997119
#   25.74848288   4.9672734    5.12029327  39.5984173   -3.66231106] 151.00891614962273
# time taken is 0.5852971076965332

# %%
sgd.predict(X_test)
# Out:
# array([142.12921588, 223.3526123 , 118.48621   , 100.96455017,
#        256.14982091, 272.78068063, 110.56573559, 117.60886538,
#        100.19412736, 204.26559125, 129.47542537, 165.98823733,
#        176.55262829, 128.92801358, 305.66836255,  89.96538852,
#        228.93532693, 151.31537058, 127.91013849, 111.31579098,
#        168.55186494, 172.78770803, 147.76150636, 169.6882289 ,
#        125.9728348 , 220.32251777, 197.23080086,  90.13181442,
#         67.62522848, 229.64350937, 254.96049801, 107.30907674,
#         81.99269034,  99.34689459, 189.94330016, 173.56705697,
#        153.0464181 , 187.23327955, 114.76816312, 201.36130286,
#        159.67271374, 115.40746007, 215.75022185, 186.14387945,
#        182.50002071, 160.97631316, 156.78444867, 269.88986281,
#         96.1533264 , 153.20843425, 244.58972614, 167.18654804,
#        164.776402  ,  91.69819173, 185.66477345,  76.87446917,
#        106.21984422,  65.647495  , 144.49667758, 187.45920136,
#        159.82460196, 161.74616529,  96.94114187, 245.8370692 ,
#        143.85022897, 105.30889751, 171.85918505, 198.79478022,
#        110.4269955 , 115.41365778, 236.11618444, 210.05243674,
#        133.62785203, 152.44973813, 140.6264282 , 129.8630881 ,
#         82.49468185,  92.33699712, 172.51358246,  92.12716741,
#        108.19970521,  95.43031284, 205.80050867, 287.71376756,
#        195.96426416, 169.56887163, 300.79442217, 220.42859109,
#         88.94227582])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(max_iter = 100, learning_rate = 'constant', eta0 = 0.01)

# %%
reg.fit(X_train, y_train)
# Out:
# C:\Users\Nadim Ansari\anaconda3\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43306332614991594
